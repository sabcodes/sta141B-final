# %%
# !pip install covidcast

# %%
#imports
import pandas as pd
import numpy as np
from plotnine import *
from datetime import datetime

# %matplotlib inline

# %%
df= pd.read_csv('us-states.csv')
df = df.replace(r'^\s*$', np.nan, regex=True)
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
statedf = df[df['state'] == 'Washington']

# %%
ggplot(df, aes(x='state', fill = 'cases', colour = 'state')) + geom_bar(stat = 'count') + theme(axis_text_x  = element_text(angle = 90, hjust = 2))
# Out:
# <ggplot: (162153143306)>

# %%
df2= pd.read_csv('us.csv')
df2 = df2.replace(r'^\s*$', np.nan, regex=True)
df2.head()
# Out:
#          date  cases deaths
# 0  2020-01-21      1      0
# 1  2020-01-22      1      0
# 2  2020-01-23      1      0
# 3  2020-01-24      2      0
# 4  2020-01-25      3      0

# %%
#converting the dates to date objects
a = df2['date'].to_list()
from datetime import datetime
dates = [] 
for i in a:
    date = datetime.strptime(str(i), '%Y-%m-%d')
    dates.append(date)
df2['dates'] = dates
df2.head()
z = ['cases', 'deaths']
df2.plot('dates', z, color='r')
# Out:
# <AxesSubplot:xlabel='dates'>

# %%
ggplot(df2, aes(x='dates'))  + geom_line(aes(y = 'cases'), color="steelblue")  + theme(axis_text_x  = element_text(angle = 90, hjust = 1)) # Geometric object to use for drawing
# Out:
# <ggplot: (162152655026)>

# %%
ggplot(df2, aes(x='dates'))  + geom_line(aes(y = 'deaths'), color="red")  + theme(axis_text_x  = element_text(angle = 90, hjust = 1)) # Geometric object to use for drawing
# Out:
# <ggplot: (162155693481)>

# %%
df3= pd.read_csv('colleges.csv')
df3 = df3.replace(r'^\s*$', np.nan, regex=True)
df3.head()
# Out:
#          date    state      county        city ipeds_id  \
# 0  2021-05-26  Alabama     Madison  Huntsville   100654
# 1  2021-05-26  Alabama  Montgomery  Montgomery   100724
# 2  2021-05-26  Alabama   Limestone      Athens   100812
# 3  2021-05-26  Alabama         Lee      Auburn   100858
# 4  2021-05-26  Alabama  Montgomery  Montgomery   100830
#
#                            college  cases  cases_2021 notes
# 0           Alabama A&M University     41         NaN   NaN
# 1         Alabama State University      2         NaN   NaN
# 2          Athens State University     45        10.0   NaN
# 3                Auburn University   2742       567.0   NaN
# 4  Auburn University at Montgomery    220        80.0   NaN

# %%
ggplot(df3, aes(x='state', fill = 'cases', colour = 'state')) + geom_bar(stat = 'count') + theme(axis_text_x  = element_text(angle = 90, hjust = 2))
# Out:
# <ggplot: (162152994976)>

# %%
dfcalicollege= df3[df3['state'] == 'California'] 
ggplot(dfcalicollege, aes(x='college', fill = 'cases', colour = 'college')) + geom_bar(stat = 'count') + theme(axis_text_x  = element_text(angle = 90, hjust = 2))
# Out:
# <ggplot: (162155585332)>

# %%
df4= dfcalicollege[(dfcalicollege['college'] == 'University of California, Davis') | (dfcalicollege['college'] == 'University of California, Merced')
                  | (dfcalicollege['college'] == 'University of California, Los Angeles')
                  | (dfcalicollege['college'] == 'University of California, Riverside')
                  | (dfcalicollege['college'] == 'University of California, Irvine')
                  | (dfcalicollege['college'] == 'University of California, Santa Cruz')
                  | (dfcalicollege['college'] == 'University of California, Santa Barbara')
                  | (dfcalicollege['college'] == 'University of California, San Diego')
                  | (dfcalicollege['college'] == 'University of California, Berkeley')] 
df4
# Out:
#            date       state         county           city ipeds_id  \
# 147  2021-05-26  California        Alameda       Berkeley   110635
# 148  2021-05-26  California           Yolo          Davis   110644
# 150  2021-05-26  California         Orange        Irvine    110653
# 151  2021-05-26  California    Los Angeles    Los Angeles   110662
# 152  2021-05-26  California         Merced         Merced   445188
# 153  2021-05-26  California      Riverside      Riverside   110671
# 154  2021-05-26  California      San Diego      San Diego   110680
# 156  2021-05-26  California  Santa Barbara  Santa Barbara   110705
# 157  2021-05-26  California     Santa Cruz     Santa Cruz   110714
#
#                                      college  cases  cases_2021  \
# 147       University of California, Berkeley   1095       679.0
# 148          University of California, Davis    678       555.0
# 150         University of California, Irvine    617       276.0
# 151    University of California, Los Angeles   3119      1461.0
# 152         University of California, Merced    124        63.0
# 153      University of California, Riverside    433       178.0
# 154      University of California, San Diego   1543       635.0
# 156  University of California, Santa Barbara    269       236.0
# 157     University of California, Santa Cruz    228       121.0
#
#                                                  notes
# 147                                                NaN
# 148                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154  Total is known to include one or more cases fr...
# 156                                                NaN
# 157                                                NaN

# %%
w = ['cases', ]
ggplot(df4, aes(x='college', weight = 'cases_2021', fill = 'college')) + geom_col(stat = "count",) + theme(axis_text_x  = element_text(angle = 90, hjust = 1))
# Out:
# <ggplot: (162160548485)>

# %%
df4['tot']=df4['cases']+df4['cases_2021']
df4.head()
# Out:
# <ipython-input-117-43770067c656>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            date       state       county         city ipeds_id  \
# 147  2021-05-26  California      Alameda     Berkeley   110635
# 148  2021-05-26  California         Yolo        Davis   110644
# 150  2021-05-26  California       Orange      Irvine    110653
# 151  2021-05-26  California  Los Angeles  Los Angeles   110662
# 152  2021-05-26  California       Merced       Merced   445188
#
#                                    college  cases  cases_2021 notes     tot
# 147     University of California, Berkeley   1095       679.0   NaN  1774.0
# 148        University of California, Davis    678       555.0   NaN  1233.0
# 150       University of California, Irvine    617       276.0   NaN   893.0
# 151  University of California, Los Angeles   3119      1461.0   NaN  4580.0
# 152       University of California, Merced    124        63.0   NaN   187.0

# %%
ggplot(df4, aes(x='college', weight = 'tot', fill = 'college')) + geom_col(stat = "count",) + theme(axis_text_x  = element_text(angle = 90, hjust = 1))
# Out:
# <ggplot: (162160530408)>

# %%
import covidcast
from datetime import date

data = covidcast.signal("fb-survey", "smoothed_cli", date(2020, 5, 1), date(2020, 5, 7),
                        "county")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dadffd244d29> in <module>
# ----> 1 import covidcast
#       2 from datetime import date
#       3
#       4 data = covidcast.signal("fb-survey", "smoothed_cli", date(2020, 5, 1), date(2020, 5, 7),
#       5                         "county")
#
# ModuleNotFoundError: No module named 'covidcast'
